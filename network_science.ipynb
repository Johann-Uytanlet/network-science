# %% [markdown]
# # Network Science
# ## Example Graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# TODO: Load dataset and other setup
gml_file_path = 'celegansneural.gml'
G = nx.read_gml(gml_file_path)

# %%
G = nx.Graph(G)

# %% [markdown]
# # Basic Graph Characteristics
# ## Node Degrees

# %%
# TODO: Implement code
# Get the degree of each node
node_degrees = G.degree()
node_degrees = sorted(node_degrees, key=lambda x: x[0])

# Print node degrees
for node, degree in node_degrees:
    print(f"Node {node}: Degree {degree}")
# Out:
# Node 1: Degree 11
# Node 10: Degree 10
# Node 100: Degree 23
# Node 101: Degree 17
# Node 102: Degree 16
# Node 103: Degree 9
# Node 104: Degree 8
# Node 105: Degree 2
# Node 106: Degree 3
# Node 107: Degree 15
# Node 108: Degree 15
# Node 109: Degree 16
# Node 11: Degree 8
# Node 110: Degree 15
# Node 111: Degree 17
# Node 112: Degree 13
# Node 113: Degree 13
# Node 114: Degree 11
# Node 115: Degree 22
# Node 116: Degree 22
# Node 117: Degree 26
# Node 118: Degree 32
# Node 119: Degree 21
# Node 12: Degree 9
# Node 120: Degree 26
# Node 121: Degree 20
# Node 122: Degree 17
# Node 123: Degree 13
# Node 124: Degree 11
# Node 125: Degree 7
# Node 126: Degree 9
# Node 127: Degree 12
# Node 128: Degree 16
# Node 129: Degree 6
# Node 13: Degree 12
# Node 130: Degree 4
# Node 131: Degree 6
# Node 132: Degree 6
# Node 133: Degree 7
# Node 134: Degree 5
# Node 135: Degree 12
# Node 136: Degree 15
# Node 137: Degree 11
# Node 138: Degree 11
# Node 139: Degree 18
# Node 14: Degree 11
# Node 140: Degree 19
# Node 141: Degree 17
# Node 142: Degree 14
# Node 143: Degree 26
# Node 144: Degree 21
# Node 145: Degree 19
# Node 146: Degree 15
# Node 147: Degree 19
# Node 148: Degree 20
# Node 149: Degree 24
# Node 15: Degree 10
# Node 150: Degree 12
# Node 151: Degree 8
# Node 152: Degree 12
# Node 153: Degree 19
# Node 154: Degree 14
# Node 155: Degree 16
# Node 156: Degree 12
# Node 157: Degree 19
# Node 158: Degree 20
# Node 159: Degree 17
# Node 16: Degree 11
# Node 160: Degree 22
# Node 161: Degree 21
# Node 162: Degree 12
# Node 163: Degree 7
# Node 164: Degree 6
# Node 165: Degree 7
# Node 166: Degree 16
# Node 167: Degree 7
# Node 168: Degree 16
# Node 169: Degree 15
# Node 17: Degree 16
# Node 170: Degree 12
# Node 171: Degree 6
# Node 172: Degree 14
# Node 173: Degree 13
# Node 174: Degree 16
# Node 175: Degree 1
# Node 176: Degree 1
# Node 177: Degree 31
# Node 178: Degree 37
# Node 179: Degree 11
# Node 18: Degree 21
# Node 180: Degree 12
# Node 181: Degree 5
# Node 182: Degree 5
# Node 183: Degree 9
# Node 184: Degree 9
# Node 185: Degree 9
# Node 186: Degree 12
# Node 187: Degree 15
# Node 188: Degree 14
# Node 189: Degree 17
# Node 19: Degree 8
# Node 190: Degree 5
# Node 191: Degree 2
# Node 192: Degree 19
# Node 193: Degree 22
# Node 194: Degree 6
# Node 195: Degree 22
# Node 196: Degree 9
# Node 197: Degree 5
# Node 198: Degree 46
# Node 199: Degree 26
# Node 2: Degree 14
# Node 20: Degree 9
# Node 200: Degree 21
# Node 201: Degree 5
# Node 202: Degree 7
# Node 203: Degree 12
# Node 204: Degree 11
# Node 205: Degree 11
# Node 206: Degree 7
# Node 207: Degree 9
# Node 208: Degree 10
# Node 209: Degree 6
# Node 21: Degree 11
# Node 210: Degree 7
# Node 211: Degree 1
# Node 212: Degree 6
# Node 213: Degree 3
# Node 214: Degree 3
# Node 215: Degree 9
# Node 216: Degree 51
# Node 217: Degree 52
# Node 218: Degree 27
# Node 219: Degree 28
# Node 22: Degree 11
# Node 220: Degree 22
# Node 221: Degree 18
# Node 222: Degree 24
# Node 223: Degree 10
# Node 224: Degree 9
# Node 225: Degree 11
# Node 226: Degree 10
# Node 227: Degree 11
# Node 228: Degree 10
# Node 229: Degree 13
# Node 23: Degree 15
# Node 230: Degree 9
# Node 231: Degree 4
# Node 232: Degree 5
# Node 233: Degree 4
# Node 234: Degree 15
# Node 235: Degree 13
# Node 236: Degree 14
# Node 237: Degree 15
# Node 238: Degree 10
# Node 239: Degree 10
# Node 24: Degree 14
# Node 240: Degree 16
# Node 241: Degree 14
# Node 242: Degree 15
# Node 243: Degree 8
# Node 244: Degree 12
# Node 245: Degree 18
# Node 246: Degree 13
# Node 247: Degree 15
# Node 248: Degree 12
# Node 249: Degree 8
# Node 25: Degree 8
# Node 250: Degree 11
# Node 251: Degree 15
# Node 252: Degree 14
# Node 253: Degree 11
# Node 254: Degree 11
# Node 255: Degree 12
# Node 256: Degree 8
# Node 257: Degree 4
# Node 258: Degree 8
# Node 259: Degree 3
# Node 26: Degree 10
# Node 260: Degree 6
# Node 261: Degree 4
# Node 262: Degree 5
# Node 263: Degree 4
# Node 264: Degree 5
# Node 265: Degree 4
# Node 266: Degree 5
# Node 267: Degree 2
# Node 268: Degree 6
# Node 269: Degree 11
# Node 27: Degree 14
# Node 270: Degree 22
# Node 271: Degree 8
# Node 272: Degree 10
# Node 273: Degree 16
# Node 274: Degree 8
# Node 275: Degree 11
# Node 276: Degree 18
# Node 277: Degree 16
# Node 278: Degree 11
# Node 279: Degree 12
# Node 28: Degree 13
# Node 280: Degree 11
# Node 281: Degree 10
# Node 282: Degree 9
# Node 29: Degree 8
# Node 291: Degree 1
# Node 292: Degree 1
# Node 293: Degree 1
# Node 294: Degree 1
# Node 295: Degree 1
# Node 296: Degree 1
# Node 297: Degree 1
# Node 298: Degree 1
# Node 299: Degree 1
# Node 3: Degree 15
# Node 30: Degree 9
# Node 300: Degree 1
# Node 301: Degree 1
# Node 302: Degree 1
# Node 303: Degree 10
# Node 305: Degree 134
# Node 306: Degree 31
# Node 31: Degree 7
# Node 32: Degree 9
# Node 33: Degree 9
# Node 34: Degree 12
# Node 35: Degree 8
# Node 36: Degree 9
# Node 37: Degree 11
# Node 38: Degree 13
# Node 39: Degree 5
# Node 4: Degree 19
# Node 40: Degree 21
# Node 41: Degree 23
# Node 42: Degree 7
# Node 43: Degree 12
# Node 44: Degree 17
# Node 45: Degree 9
# Node 46: Degree 17
# Node 47: Degree 19
# Node 48: Degree 16
# Node 49: Degree 4
# Node 5: Degree 8
# Node 50: Degree 4
# Node 51: Degree 29
# Node 52: Degree 33
# Node 53: Degree 8
# Node 54: Degree 9
# Node 55: Degree 20
# Node 56: Degree 20
# Node 57: Degree 15
# Node 58: Degree 15
# Node 59: Degree 6
# Node 6: Degree 8
# Node 60: Degree 6
# Node 61: Degree 15
# Node 62: Degree 17
# Node 63: Degree 8
# Node 64: Degree 5
# Node 65: Degree 2
# Node 66: Degree 5
# Node 67: Degree 10
# Node 68: Degree 6
# Node 69: Degree 11
# Node 7: Degree 14
# Node 70: Degree 10
# Node 71: Degree 77
# Node 72: Degree 74
# Node 73: Degree 53
# Node 74: Degree 53
# Node 75: Degree 49
# Node 76: Degree 53
# Node 77: Degree 52
# Node 78: Degree 54
# Node 79: Degree 20
# Node 8: Degree 17
# Node 80: Degree 21
# Node 81: Degree 29
# Node 82: Degree 30
# Node 83: Degree 7
# Node 84: Degree 11
# Node 85: Degree 10
# Node 86: Degree 10
# Node 87: Degree 12
# Node 88: Degree 12
# Node 89: Degree 32
# Node 9: Degree 10
# Node 90: Degree 36
# Node 91: Degree 24
# Node 92: Degree 18
# Node 93: Degree 19
# Node 94: Degree 21
# Node 95: Degree 25
# Node 96: Degree 29
# Node 97: Degree 12
# Node 98: Degree 14
# Node 99: Degree 20

# %% [markdown]
# ## Average Degree

# %%
# TODO: Implement code
average_degree = sum(dict(G.degree()).values()) / len(G)
print(f"Average Degree: {average_degree}")
# Out:
# Average Degree: 14.464646464646465

# %% [markdown]
# ## Average Path Length

# %%
# TODO: Implement code
average_shortest_path_length = nx.average_shortest_path_length(G)

# Print the result
print(f"Average Shortest Path Length: {average_shortest_path_length}")
# Out:
# Average Shortest Path Length: 2.455318955318955

# %% [markdown]
# ## Diameter

# %%
# TODO: Implement code
diameter = nx.diameter(G)

# Print the result
print(f"Diameter: {diameter}")
# Out:
# Diameter: 5

# %% [markdown]
# ## Clustering Coefficient

# %%
# TODO: Implement code
clustering_coefficient = nx.clustering(G)

# Print clustering coefficient for each node
for node, cc in clustering_coefficient.items():
    print(f"Node {node}: Clustering Coefficient {cc}")
# Out:
# Node 1: Clustering Coefficient 0.3090909090909091
# Node 51: Clustering Coefficient 0.16748768472906403
# Node 72: Clustering Coefficient 0.11218067382450944
# Node 77: Clustering Coefficient 0.11236802413273002
# Node 78: Clustering Coefficient 0.11809923130677848
# Node 2: Clustering Coefficient 0.3076923076923077
# Node 90: Clustering Coefficient 0.14603174603174604
# Node 92: Clustering Coefficient 0.21568627450980393
# Node 158: Clustering Coefficient 0.20526315789473684
# Node 159: Clustering Coefficient 0.18382352941176472
# Node 113: Clustering Coefficient 0.358974358974359
# Node 69: Clustering Coefficient 0.38181818181818183
# Node 71: Clustering Coefficient 0.10628844839371156
# Node 89: Clustering Coefficient 0.16532258064516128
# Node 91: Clustering Coefficient 0.18840579710144928
# Node 3: Clustering Coefficient 0.14285714285714285
# Node 47: Clustering Coefficient 0.2222222222222222
# Node 9: Clustering Coefficient 0.28888888888888886
# Node 17: Clustering Coefficient 0.19166666666666668
# Node 21: Clustering Coefficient 0.23636363636363636
# Node 93: Clustering Coefficient 0.10526315789473684
# Node 94: Clustering Coefficient 0.08571428571428572
# Node 23: Clustering Coefficient 0.22857142857142856
# Node 121: Clustering Coefficient 0.2789473684210526
# Node 125: Clustering Coefficient 0.09523809523809523
# Node 131: Clustering Coefficient 0.06666666666666667
# Node 31: Clustering Coefficient 0.38095238095238093
# Node 4: Clustering Coefficient 0.14035087719298245
# Node 60: Clustering Coefficient 0.13333333333333333
# Node 10: Clustering Coefficient 0.3111111111111111
# Node 16: Clustering Coefficient 0.38181818181818183
# Node 18: Clustering Coefficient 0.15714285714285714
# Node 22: Clustering Coefficient 0.2909090909090909
# Node 24: Clustering Coefficient 0.2087912087912088
# Node 97: Clustering Coefficient 0.3181818181818182
# Node 122: Clustering Coefficient 0.22794117647058823
# Node 126: Clustering Coefficient 0.08333333333333333
# Node 132: Clustering Coefficient 0.2
# Node 32: Clustering Coefficient 0.3333333333333333
# Node 303: Clustering Coefficient 0.044444444444444446
# Node 5: Clustering Coefficient 0.42857142857142855
# Node 7: Clustering Coefficient 0.27472527472527475
# Node 222: Clustering Coefficient 0.18115942028985507
# Node 101: Clustering Coefficient 0.25
# Node 305: Clustering Coefficient 0.04455167770171698
# Node 6: Clustering Coefficient 0.35714285714285715
# Node 102: Clustering Coefficient 0.24166666666666667
# Node 99: Clustering Coefficient 0.25263157894736843
# Node 100: Clustering Coefficient 0.21739130434782608
# Node 27: Clustering Coefficient 0.16483516483516483
# Node 8: Clustering Coefficient 0.2867647058823529
# Node 26: Clustering Coefficient 0.13333333333333333
# Node 44: Clustering Coefficient 0.21323529411764705
# Node 37: Clustering Coefficient 0.2909090909090909
# Node 11: Clustering Coefficient 0.21428571428571427
# Node 19: Clustering Coefficient 0.21428571428571427
# Node 29: Clustering Coefficient 0.32142857142857145
# Node 12: Clustering Coefficient 0.2777777777777778
# Node 41: Clustering Coefficient 0.17391304347826086
# Node 118: Clustering Coefficient 0.12298387096774194
# Node 25: Clustering Coefficient 0.17857142857142858
# Node 30: Clustering Coefficient 0.3055555555555556
# Node 13: Clustering Coefficient 0.22727272727272727
# Node 143: Clustering Coefficient 0.12923076923076923
# Node 28: Clustering Coefficient 0.19230769230769232
# Node 43: Clustering Coefficient 0.22727272727272727
# Node 14: Clustering Coefficient 0.21818181818181817
# Node 144: Clustering Coefficient 0.19523809523809524
# Node 20: Clustering Coefficient 0.16666666666666666
# Node 34: Clustering Coefficient 0.2727272727272727
# Node 15: Clustering Coefficient 0.3111111111111111
# Node 40: Clustering Coefficient 0.1619047619047619
# Node 128: Clustering Coefficient 0.16666666666666666
# Node 139: Clustering Coefficient 0.20261437908496732
# Node 140: Clustering Coefficient 0.1695906432748538
# Node 108: Clustering Coefficient 0.3047619047619048
# Node 35: Clustering Coefficient 0.42857142857142855
# Node 107: Clustering Coefficient 0.22857142857142856
# Node 133: Clustering Coefficient 0.047619047619047616
# Node 134: Clustering Coefficient 0
# Node 105: Clustering Coefficient 0
# Node 106: Clustering Coefficient 0
# Node 36: Clustering Coefficient 0.25
# Node 33: Clustering Coefficient 0.19444444444444445
# Node 73: Clustering Coefficient 0.19085631349782292
# Node 136: Clustering Coefficient 0.13333333333333333
# Node 74: Clustering Coefficient 0.18650217706821481
# Node 161: Clustering Coefficient 0.19523809523809524
# Node 129: Clustering Coefficient 0.2
# Node 135: Clustering Coefficient 0.10606060606060606
# Node 120: Clustering Coefficient 0.2
# Node 38: Clustering Coefficient 0.21794871794871795
# Node 39: Clustering Coefficient 0
# Node 160: Clustering Coefficient 0.12554112554112554
# Node 130: Clustering Coefficient 0.16666666666666666
# Node 174: Clustering Coefficient 0.20833333333333334
# Node 42: Clustering Coefficient 0.23809523809523808
# Node 189: Clustering Coefficient 0.2647058823529412
# Node 82: Clustering Coefficient 0.27586206896551724
# Node 70: Clustering Coefficient 0.35555555555555557
# Node 45: Clustering Coefficient 0.2777777777777778
# Node 141: Clustering Coefficient 0.22794117647058823
# Node 55: Clustering Coefficient 0.20526315789473684
# Node 119: Clustering Coefficient 0.24285714285714285
# Node 137: Clustering Coefficient 0.12727272727272726
# Node 46: Clustering Coefficient 0.27205882352941174
# Node 142: Clustering Coefficient 0.17582417582417584
# Node 114: Clustering Coefficient 0.32727272727272727
# Node 56: Clustering Coefficient 0.21578947368421053
# Node 62: Clustering Coefficient 0.29411764705882354
# Node 86: Clustering Coefficient 0.4
# Node 193: Clustering Coefficient 0.30735930735930733
# Node 138: Clustering Coefficient 0.2
# Node 109: Clustering Coefficient 0.275
# Node 52: Clustering Coefficient 0.1571969696969697
# Node 58: Clustering Coefficient 0.3142857142857143
# Node 61: Clustering Coefficient 0.29523809523809524
# Node 75: Clustering Coefficient 0.17006802721088435
# Node 76: Clustering Coefficient 0.1567489114658926
# Node 81: Clustering Coefficient 0.29064039408866993
# Node 85: Clustering Coefficient 0.28888888888888886
# Node 48: Clustering Coefficient 0.31666666666666665
# Node 110: Clustering Coefficient 0.26666666666666666
# Node 80: Clustering Coefficient 0.22857142857142856
# Node 88: Clustering Coefficient 0.48484848484848486
# Node 216: Clustering Coefficient 0.17098039215686275
# Node 49: Clustering Coefficient 0.5
# Node 54: Clustering Coefficient 0.19444444444444445
# Node 50: Clustering Coefficient 0.5
# Node 154: Clustering Coefficient 0.4835164835164835
# Node 96: Clustering Coefficient 0.2044334975369458
# Node 127: Clustering Coefficient 0.21212121212121213
# Node 95: Clustering Coefficient 0.19
# Node 166: Clustering Coefficient 0.25
# Node 53: Clustering Coefficient 0.07142857142857142
# Node 57: Clustering Coefficient 0.2857142857142857
# Node 63: Clustering Coefficient 0.6428571428571429
# Node 198: Clustering Coefficient 0.12367149758454106
# Node 87: Clustering Coefficient 0.45454545454545453
# Node 84: Clustering Coefficient 0.3090909090909091
# Node 59: Clustering Coefficient 0.4666666666666667
# Node 67: Clustering Coefficient 0.3333333333333333
# Node 178: Clustering Coefficient 0.15615615615615616
# Node 64: Clustering Coefficient 0.6
# Node 65: Clustering Coefficient 1.0
# Node 220: Clustering Coefficient 0.18181818181818182
# Node 66: Clustering Coefficient 0.6
# Node 68: Clustering Coefficient 0.4
# Node 221: Clustering Coefficient 0.1895424836601307
# Node 111: Clustering Coefficient 0.25
# Node 112: Clustering Coefficient 0.23076923076923078
# Node 146: Clustering Coefficient 0.5047619047619047
# Node 225: Clustering Coefficient 0.4
# Node 186: Clustering Coefficient 0.5
# Node 226: Clustering Coefficient 0.5555555555555556
# Node 227: Clustering Coefficient 0.4909090909090909
# Node 228: Clustering Coefficient 0.4888888888888889
# Node 229: Clustering Coefficient 0.4358974358974359
# Node 230: Clustering Coefficient 0.4722222222222222
# Node 150: Clustering Coefficient 0.3484848484848485
# Node 234: Clustering Coefficient 0.41904761904761906
# Node 235: Clustering Coefficient 0.4358974358974359
# Node 236: Clustering Coefficient 0.38461538461538464
# Node 237: Clustering Coefficient 0.3904761904761905
# Node 238: Clustering Coefficient 0.35555555555555557
# Node 239: Clustering Coefficient 0.4222222222222222
# Node 187: Clustering Coefficient 0.42857142857142855
# Node 188: Clustering Coefficient 0.37362637362637363
# Node 240: Clustering Coefficient 0.30833333333333335
# Node 242: Clustering Coefficient 0.22857142857142856
# Node 203: Clustering Coefficient 0.5
# Node 179: Clustering Coefficient 0.41818181818181815
# Node 217: Clustering Coefficient 0.17722473604826547
# Node 162: Clustering Coefficient 0.2878787878787879
# Node 164: Clustering Coefficient 0.26666666666666666
# Node 249: Clustering Coefficient 0.42857142857142855
# Node 250: Clustering Coefficient 0.34545454545454546
# Node 195: Clustering Coefficient 0.3116883116883117
# Node 251: Clustering Coefficient 0.42857142857142855
# Node 252: Clustering Coefficient 0.4065934065934066
# Node 253: Clustering Coefficient 0.41818181818181815
# Node 254: Clustering Coefficient 0.38181818181818183
# Node 255: Clustering Coefficient 0.3333333333333333
# Node 197: Clustering Coefficient 0.5
# Node 204: Clustering Coefficient 0.5272727272727272
# Node 180: Clustering Coefficient 0.3484848484848485
# Node 163: Clustering Coefficient 0.3333333333333333
# Node 117: Clustering Coefficient 0.24615384615384617
# Node 256: Clustering Coefficient 0.2857142857142857
# Node 276: Clustering Coefficient 0.3137254901960784
# Node 306: Clustering Coefficient 0.07311827956989247
# Node 177: Clustering Coefficient 0.15053763440860216
# Node 241: Clustering Coefficient 0.27472527472527475
# Node 200: Clustering Coefficient 0.2619047619047619
# Node 215: Clustering Coefficient 0.6666666666666666
# Node 199: Clustering Coefficient 0.19384615384615383
# Node 165: Clustering Coefficient 0.5714285714285714
# Node 169: Clustering Coefficient 0.38095238095238093
# Node 79: Clustering Coefficient 0.21052631578947367
# Node 148: Clustering Coefficient 0.30526315789473685
# Node 168: Clustering Coefficient 0.275
# Node 145: Clustering Coefficient 0.40350877192982454
# Node 147: Clustering Coefficient 0.2807017543859649
# Node 192: Clustering Coefficient 0.34502923976608185
# Node 219: Clustering Coefficient 0.2777777777777778
# Node 157: Clustering Coefficient 0.3333333333333333
# Node 172: Clustering Coefficient 0.3076923076923077
# Node 218: Clustering Coefficient 0.28205128205128205
# Node 83: Clustering Coefficient 0.23809523809523808
# Node 98: Clustering Coefficient 0.2857142857142857
# Node 124: Clustering Coefficient 0.43636363636363634
# Node 103: Clustering Coefficient 0.3333333333333333
# Node 104: Clustering Coefficient 0.21428571428571427
# Node 115: Clustering Coefficient 0.23376623376623376
# Node 123: Clustering Coefficient 0.28205128205128205
# Node 156: Clustering Coefficient 0.30303030303030304
# Node 170: Clustering Coefficient 0.16666666666666666
# Node 183: Clustering Coefficient 0.6388888888888888
# Node 116: Clustering Coefficient 0.18181818181818182
# Node 153: Clustering Coefficient 0.30409356725146197
# Node 224: Clustering Coefficient 0.4166666666666667
# Node 196: Clustering Coefficient 0.5277777777777778
# Node 214: Clustering Coefficient 0.3333333333333333
# Node 213: Clustering Coefficient 0.3333333333333333
# Node 155: Clustering Coefficient 0.475
# Node 173: Clustering Coefficient 0.1794871794871795
# Node 149: Clustering Coefficient 0.34057971014492755
# Node 275: Clustering Coefficient 0.38181818181818183
# Node 205: Clustering Coefficient 0.32727272727272727
# Node 206: Clustering Coefficient 0.42857142857142855
# Node 151: Clustering Coefficient 0.39285714285714285
# Node 277: Clustering Coefficient 0.2833333333333333
# Node 152: Clustering Coefficient 0.2727272727272727
# Node 245: Clustering Coefficient 0.2549019607843137
# Node 278: Clustering Coefficient 0.32727272727272727
# Node 201: Clustering Coefficient 0.1
# Node 202: Clustering Coefficient 0.09523809523809523
# Node 167: Clustering Coefficient 0.5238095238095238
# Node 269: Clustering Coefficient 0.509090909090909
# Node 184: Clustering Coefficient 0.3055555555555556
# Node 171: Clustering Coefficient 0.26666666666666666
# Node 185: Clustering Coefficient 0.3055555555555556
# Node 175: Clustering Coefficient 0
# Node 176: Clustering Coefficient 0
# Node 272: Clustering Coefficient 0.4666666666666667
# Node 270: Clustering Coefficient 0.2510822510822511
# Node 258: Clustering Coefficient 0.2857142857142857
# Node 181: Clustering Coefficient 0.5
# Node 182: Clustering Coefficient 0.4
# Node 274: Clustering Coefficient 0.42857142857142855
# Node 190: Clustering Coefficient 0.6
# Node 191: Clustering Coefficient 1.0
# Node 194: Clustering Coefficient 0.5333333333333333
# Node 244: Clustering Coefficient 0.3181818181818182
# Node 260: Clustering Coefficient 0.6
# Node 207: Clustering Coefficient 0.5555555555555556
# Node 223: Clustering Coefficient 0.4
# Node 208: Clustering Coefficient 0.5777777777777777
# Node 209: Clustering Coefficient 0.6666666666666666
# Node 210: Clustering Coefficient 0.3333333333333333
# Node 211: Clustering Coefficient 0
# Node 212: Clustering Coefficient 0.5333333333333333
# Node 261: Clustering Coefficient 0.3333333333333333
# Node 262: Clustering Coefficient 0.3
# Node 263: Clustering Coefficient 0.3333333333333333
# Node 264: Clustering Coefficient 0.3
# Node 265: Clustering Coefficient 0.3333333333333333
# Node 266: Clustering Coefficient 0.3
# Node 282: Clustering Coefficient 0.3611111111111111
# Node 279: Clustering Coefficient 0.2878787878787879
# Node 231: Clustering Coefficient 0.8333333333333334
# Node 280: Clustering Coefficient 0.32727272727272727
# Node 232: Clustering Coefficient 0.7
# Node 281: Clustering Coefficient 0.3333333333333333
# Node 233: Clustering Coefficient 0.8333333333333334
# Node 246: Clustering Coefficient 0.28205128205128205
# Node 247: Clustering Coefficient 0.24761904761904763
# Node 248: Clustering Coefficient 0.25757575757575757
# Node 243: Clustering Coefficient 0.35714285714285715
# Node 257: Clustering Coefficient 0.6666666666666666
# Node 259: Clustering Coefficient 0.6666666666666666
# Node 267: Clustering Coefficient 1.0
# Node 268: Clustering Coefficient 0.8
# Node 271: Clustering Coefficient 0.5
# Node 273: Clustering Coefficient 0.175
# Node 291: Clustering Coefficient 0
# Node 292: Clustering Coefficient 0
# Node 293: Clustering Coefficient 0
# Node 294: Clustering Coefficient 0
# Node 295: Clustering Coefficient 0
# Node 296: Clustering Coefficient 0
# Node 297: Clustering Coefficient 0
# Node 298: Clustering Coefficient 0
# Node 299: Clustering Coefficient 0
# Node 300: Clustering Coefficient 0
# Node 301: Clustering Coefficient 0
# Node 302: Clustering Coefficient 0

# %%
# TODO: Implement code
global_clustering_coefficient = nx.average_clustering(G)
print(f"Global Clustering Coefficient: {global_clustering_coefficient}")
# Out:
# Global Clustering Coefficient: 0.29236329783219017

# %% [markdown]
# # Centralities
# ## Degree

# %%
# Degree distribution
degree_distribution = dict(G.degree())

# Identify hubs (nodes with high degree)
hubs = sorted(degree_distribution, key=degree_distribution.get, reverse=True)[:5]

# Extract degrees and nodes
nodes, degrees = zip(*degree_distribution.items())

# Create a bar graph
plt.bar(nodes, degrees, color='skyblue')

# Highlight hubs with a different color
for hub in hubs:
    plt.bar(hub, degree_distribution[hub], color='red')

# Add labels and title
plt.xlabel('Node')
plt.ylabel('Degree')
plt.title('Degree Distribution with Hubs Highlighted')

# Show the plot
plt.show()

print(f"Hubs: {hubs}")
# Out:
# Hubs: ['305', '71', '72', '78', '73']

# %% [markdown]
# ## Betweenness

# %%
# TODO: Implement code
# Calculate betweenness centrality
betweenness_centrality = nx.betweenness_centrality(G)

# Identify nodes with the highest betweenness
highest_betweenness_nodes = sorted(betweenness_centrality, key=betweenness_centrality.get, reverse=True)[:5]
print(f"Nodes with Highest Betweenness Centrality: {highest_betweenness_nodes}")
# Out:
# Nodes with Highest Betweenness Centrality: ['305', '71', '72', '306', '78']

# %% [markdown]
# ## Closeness

# %%
# TODO: Implement code
# Calculate closeness centrality
closeness_centrality = nx.closeness_centrality(G)

# Identify nodes with the highest closeness centrality
highest_closeness_nodes = sorted(closeness_centrality, key=closeness_centrality.get, reverse=True)[:5]
print(f"Nodes with Highest Closeness Centrality: {highest_closeness_nodes}")
# Out:
# Nodes with Highest Closeness Centrality: ['305', '71', '72', '74', '77']

# %% [markdown]
# ## Eigenvector

# %%
# TODO: Implement code
# Calculate eigenvector centrality
eigenvector_centrality = nx.eigenvector_centrality(G)

# Identify influential nodes
influential_nodes = sorted(eigenvector_centrality, key=eigenvector_centrality.get, reverse=True)[:5]
print(f"Influential Nodes: {influential_nodes}")
# Out:
# Influential Nodes: ['71', '72', '305', '73', '74']

# %% [markdown]
# # Graph Visualization

# %%
pos = nx.spring_layout(G)  # You can choose different layout algorithms
nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=500, node_color='skyblue', edge_color='gray', linewidths=0.5)

# Show the plot
plt.show()

# %% [markdown]
# # Robustness and Vulnerability
# ## Robustness

# %%
# TODO: Implement code

# %% [markdown]
# ## Vulnerability

# %%
# TODO: Implement code
